# %% [markdown]
# # RFM

# %% [markdown]
# ## Data Processing

# %%
import pandas as pd
df = pd.read_csv('transaction_data.csv')
df
# Out:
#        Unnamed: 0  transaction_id  product_id  CustomerID  \
# 0               0               1           2        2950
# 1               1               2           3        3120
# 2               2               3          37         402
# 3               3               4          88        3135
# 4               4               5          78         787
# ...           ...             ...         ...         ...
# 19995       19995           19996          51        1018
# 19996       19996           19997          41         127
# 19997       19997           19998          87        2284
# 19998       19998           19999           6        2764
# 19999       19999           20000          11        1144
#
#           transaction_date online_order order_status           brand  \
# 0      2017-02-25 00:00:00        False     Approved           Solex
# 1      2017-05-21 00:00:00         True     Approved   Trek Bicycles
# 2      2017-10-16 00:00:00        False     Approved      OHM Cycles
# 3      2017-08-31 00:00:00        False     Approved  Norco Bicycles
# 4      2017-10-01 00:00:00         True     Approved  Giant Bicycles
# ...                    ...          ...          ...             ...
# 19995  2017-06-24 00:00:00         True     Approved      OHM Cycles
# 19996  2017-11-09 00:00:00         True     Approved           Solex
# 19997  2017-04-14 00:00:00         True     Approved      OHM Cycles
# 19998  2017-07-03 00:00:00        False     Approved      OHM Cycles
# 19999  2017-09-22 00:00:00         True     Approved   Trek Bicycles
#
#       product_line product_class product_size  list_price  standard_cost  \
# 0         Standard        medium       medium       71.49          53.62
# 1         Standard        medium        large     2091.47         388.92
# 2         Standard           low       medium     1793.43         248.82
# 3         Standard        medium       medium     1198.46         381.10
# 4         Standard        medium        large     1765.30         709.48
# ...            ...           ...          ...         ...            ...
# 19995     Standard          high       medium     2005.66        1203.40
# 19996         Road        medium       medium      416.98         312.74
# 19997     Standard        medium       medium     1636.90          44.71
# 19998     Standard          high       medium      227.88         136.73
# 19999     Standard        medium        small     1775.81        1580.47
#
#        product_first_sold_date InvoiceDate
# 0                      41245.0  2017-02-25
# 1                      41701.0  2017-05-21
# 2                      36361.0  2017-10-16
# 3                      36145.0  2017-08-31
# 4                      42226.0  2017-10-01
# ...                        ...         ...
# 19995                  37823.0  2017-06-24
# 19996                  35560.0  2017-11-09
# 19997                  40410.0  2017-04-14
# 19998                  38216.0  2017-07-03
# 19999                  36334.0  2017-09-22
#
# [20000 rows x 15 columns]

# %% [markdown]
# ## Missing Value

# %%
# Untuk mengecek missing value

df.isna().sum()
# Out:
# Unnamed: 0                   0
# transaction_id               0
# product_id                   0
# CustomerID                   0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# InvoiceDate                  0
# dtype: int64

# %%
# menghitung persentase missing values
df.isna().sum() / len(df) * 100
# Out:
# Unnamed: 0                 0.000
# transaction_id             0.000
# product_id                 0.000
# CustomerID                 0.000
# transaction_date           0.000
# online_order               1.800
# order_status               0.000
# brand                      0.985
# product_line               0.985
# product_class              0.985
# product_size               0.985
# list_price                 0.000
# standard_cost              0.985
# product_first_sold_date    0.985
# InvoiceDate                0.000
# dtype: float64

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#        transaction_id  product_id  CustomerID     transaction_date  \
# 0                   1           2        2950  2017-02-25 00:00:00
# 1                   2           3        3120  2017-05-21 00:00:00
# 2                   3          37         402  2017-10-16 00:00:00
# 3                   4          88        3135  2017-08-31 00:00:00
# 4                   5          78         787  2017-10-01 00:00:00
# ...               ...         ...         ...                  ...
# 19440           19996          51        1018  2017-06-24 00:00:00
# 19441           19997          41         127  2017-11-09 00:00:00
# 19442           19998          87        2284  2017-04-14 00:00:00
# 19443           19999           6        2764  2017-07-03 00:00:00
# 19444           20000          11        1144  2017-09-22 00:00:00
#
#       online_order order_status           brand product_line product_class  \
# 0            False     Approved           Solex     Standard        medium
# 1             True     Approved   Trek Bicycles     Standard        medium
# 2            False     Approved      OHM Cycles     Standard           low
# 3            False     Approved  Norco Bicycles     Standard        medium
# 4             True     Approved  Giant Bicycles     Standard        medium
# ...            ...          ...             ...          ...           ...
# 19440         True     Approved      OHM Cycles     Standard          high
# 19441         True     Approved           Solex         Road        medium
# 19442         True     Approved      OHM Cycles     Standard        medium
# 19443        False     Approved      OHM Cycles     Standard          high
# 19444         True     Approved   Trek Bicycles     Standard        medium
#
#       product_size  list_price  standard_cost  product_first_sold_date  \
# 0           medium       71.49          53.62                  41245.0
# 1            large     2091.47         388.92                  41701.0
# 2           medium     1793.43         248.82                  36361.0
# 3           medium     1198.46         381.10                  36145.0
# 4            large     1765.30         709.48                  42226.0
# ...            ...         ...            ...                      ...
# 19440       medium     2005.66        1203.40                  37823.0
# 19441       medium      416.98         312.74                  35560.0
# 19442       medium     1636.90          44.71                  40410.0
# 19443       medium      227.88         136.73                  38216.0
# 19444        small     1775.81        1580.47                  36334.0
#
#       InvoiceDate
# 0      2017-02-25
# 1      2017-05-21
# 2      2017-10-16
# 3      2017-08-31
# 4      2017-10-01
# ...           ...
# 19440  2017-06-24
# 19441  2017-11-09
# 19442  2017-04-14
# 19443  2017-07-03
# 19444  2017-09-22
#
# [19445 rows x 14 columns]

# %% [markdown]
# ## Data Duplikat

# %%
# menghitung jumlah yang sama
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Variabel Numerik

# %%
# cara mengambil yang numerik
numerik = df.select_dtypes(include='number') #yang mengnadung float dan int
numerik
# Out:
#        transaction_id  product_id  CustomerID  list_price  standard_cost  \
# 0                   1           2        2950       71.49          53.62
# 1                   2           3        3120     2091.47         388.92
# 2                   3          37         402     1793.43         248.82
# 3                   4          88        3135     1198.46         381.10
# 4                   5          78         787     1765.30         709.48
# ...               ...         ...         ...         ...            ...
# 19440           19996          51        1018     2005.66        1203.40
# 19441           19997          41         127      416.98         312.74
# 19442           19998          87        2284     1636.90          44.71
# 19443           19999           6        2764      227.88         136.73
# 19444           20000          11        1144     1775.81        1580.47
#
#        product_first_sold_date
# 0                      41245.0
# 1                      41701.0
# 2                      36361.0
# 3                      36145.0
# 4                      42226.0
# ...                        ...
# 19440                  37823.0
# 19441                  35560.0
# 19442                  40410.0
# 19443                  38216.0
# 19444                  36334.0
#
# [19445 rows x 6 columns]

# %% [markdown]
# ## Statistika Diskriptif

# %%
round(numerik.describe(),2)
# Out:
#        transaction_id  product_id  CustomerID  list_price  standard_cost  \
# count        19445.00    19445.00    19445.00    19445.00       19445.00
# mean          9989.26       45.80     1739.47     1107.34         555.59
# std           5779.67       30.57     1011.89      582.66         405.60
# min              1.00        0.00        1.00       12.01           7.21
# 25%           4976.00       18.00      857.00      575.27         215.14
# 50%           9985.00       45.00     1741.00     1163.89         507.58
# 75%          14997.00       72.00     2615.00     1635.30         795.10
# max          20000.00      100.00     5034.00     2091.47        1759.85
#
#        product_first_sold_date
# count                 19445.00
# mean                  38201.76
# std                    2878.07
# min                   33259.00
# 25%                   35667.00
# 50%                   38216.00
# 75%                   40672.00
# max                   42710.00

# %% [markdown]
# 1. transaction_id (ID Transaksi)
#   - ID transaksi berkisar dari 1 hingga 20.000, menunjukkan bahwa terdapat 19.445 transaksi unik di dataset.
#   - Nilai mean sekitar 9.989, yang menunjukkan bahwa transaksi tersebar cukup merata di antara rentang ID.
# 2. product_id (ID Produk)
#   - ID produk berkisar dari 0 hingga 100, dengan nilai rata-rata sekitar 45.8.
#   - Standar deviasi sekitar 30.57, menunjukkan ada variasi yang cukup besar dalam ID produk.
# 3. CustomerID (ID Pelanggan)
#   - Terdapat 19.445 pelanggan unik, dengan ID berkisar dari 1 hingga 5034.
#   - Nilai rata-rata 1739.46, menunjukkan distribusi pelanggan cukup luas.
# 4. list_price (Harga Produk)
#   - Harga produk berkisar antara 12.01 hingga 2091.47.
#   - Harga rata-rata sekitar 1107.34, dengan standar deviasi 582.66, menunjukkan variasi harga yang cukup besar.
# 5. standard_cost (Biaya Standar)
#   - Biaya produksi berkisar antara 7.21 hingga 1759.85.
#   - Rata-rata biaya produksi adalah 555.59, dengan standar deviasi 405.59, menunjukkan bahwa ada produk yang jauh lebih mahal untuk diproduksi dibandingkan yang lain.
# 6. product_first_sold_date (Tanggal Produk Pertama Dijual)
#   - Nilai berkisar antara 33.259 hingga 42.710, yang tampaknya merupakan representasi tanggal dalam format numerik (mungkin format Julian atau Unix Timestamp).
#   - Rata-rata sekitar 38.201, yang bisa dikonversi ke format tanggal untuk interpretasi yang lebih jelas.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# atur size dari figure
plt.figure(figsize=(15,10)) #kolom dan baris

for posisi, nama_kolom in zip(range(1,10), numerik.columns):
    plt.subplot(3,3,posisi)
    sns.histplot(df[nama_kolom], kde = True)

plt.show()

# %%
from scipy.stats import kstest

for nama_kolom in numerik.columns:
  stat, pval = kstest(df[nama_kolom], 'norm')
  if pval < 0.05:
      print(f'Kolom {nama_kolom} distribusi tidak normal (Tolak H0)')
  else:
      print(f'Kolom {nama_kolom} distribusi normal (Terima H0)')
# Out:
# Kolom transaction_id distribusi tidak normal (Tolak H0)
# Kolom product_id distribusi tidak normal (Tolak H0)
# Kolom CustomerID distribusi tidak normal (Tolak H0)
# Kolom list_price distribusi tidak normal (Tolak H0)
# Kolom standard_cost distribusi tidak normal (Tolak H0)
# Kolom product_first_sold_date distribusi tidak normal (Tolak H0)

# %%
# atur size dari figure
plt.figure(figsize = (15,10)) # kolom, baris

for posisi, nama_kolom in zip(range(1,10), numerik.columns): # posisi 1 sampai 9
    plt.subplot(3,3,posisi) # jumlah baris, jumlah kolom, posisi
    sns.boxplot(x = df[nama_kolom])

plt.show()

# %%
for nama_kolom in numerik.columns:
    q1 = df[nama_kolom].quantile(0.25)
    q3 = df[nama_kolom].quantile(0.75)
    iqr = q3 - q1
    bebas_atas = q3 + (iqr * 1.5)
    bebas_bawah = q1 - (iqr * 1.5)
    jumlah_outliers = len(df[(df[nama_kolom] > bebas_atas) | (df[nama_kolom] < bebas_bawah)])
    print(f'Jumlah outliers: {nama_kolom} {jumlah_outliers}')
# Out:
# Jumlah outliers: transaction_id 0
# Jumlah outliers: product_id 0
# Jumlah outliers: CustomerID 0
# Jumlah outliers: list_price 0
# Jumlah outliers: standard_cost 189
# Jumlah outliers: product_first_sold_date 0

# %%
numerik.corr()
# Out:
#                          transaction_id  product_id  CustomerID  list_price  \
# transaction_id                 1.000000   -0.011633    0.002779   -0.006391
# product_id                    -0.011633    1.000000    0.003369    0.090085
# CustomerID                     0.002779    0.003369    1.000000    0.011671
# list_price                    -0.006391    0.090085    0.011671    1.000000
# standard_cost                 -0.002293    0.038830    0.006870    0.551666
# product_first_sold_date        0.004391   -0.054155   -0.002306    0.059164
#
#                          standard_cost  product_first_sold_date
# transaction_id               -0.002293                 0.004391
# product_id                    0.038830                -0.054155
# CustomerID                    0.006870                -0.002306
# list_price                    0.551666                 0.059164
# standard_cost                 1.000000                 0.030714
# product_first_sold_date       0.030714                 1.000000

# %%
sns.heatmap(numerik.corr(), annot = True)
plt.show()

# %% [markdown]
# ## Variabel Kategorik

# %%
kategorik = df.select_dtypes(include = 'object') # sama saja
kategorik
# Out:
#           transaction_date online_order order_status           brand  \
# 0      2017-02-25 00:00:00        False     Approved           Solex
# 1      2017-05-21 00:00:00         True     Approved   Trek Bicycles
# 2      2017-10-16 00:00:00        False     Approved      OHM Cycles
# 3      2017-08-31 00:00:00        False     Approved  Norco Bicycles
# 4      2017-10-01 00:00:00         True     Approved  Giant Bicycles
# ...                    ...          ...          ...             ...
# 19440  2017-06-24 00:00:00         True     Approved      OHM Cycles
# 19441  2017-11-09 00:00:00         True     Approved           Solex
# 19442  2017-04-14 00:00:00         True     Approved      OHM Cycles
# 19443  2017-07-03 00:00:00        False     Approved      OHM Cycles
# 19444  2017-09-22 00:00:00         True     Approved   Trek Bicycles
#
#       product_line product_class product_size InvoiceDate
# 0         Standard        medium       medium  2017-02-25
# 1         Standard        medium        large  2017-05-21
# 2         Standard           low       medium  2017-10-16
# 3         Standard        medium       medium  2017-08-31
# 4         Standard        medium        large  2017-10-01
# ...            ...           ...          ...         ...
# 19440     Standard          high       medium  2017-06-24
# 19441         Road        medium       medium  2017-11-09
# 19442     Standard        medium       medium  2017-04-14
# 19443     Standard          high       medium  2017-07-03
# 19444     Standard        medium        small  2017-09-22
#
# [19445 rows x 8 columns]

# %%
kategorik.describe()
# Out:
#            transaction_date online_order order_status  brand product_line  \
# count                 19445        19445        19445  19445        19445
# unique                  364            2            2      6            4
# top     2017-08-18 00:00:00         True     Approved  Solex     Standard
# freq                     81         9739        19273   4169        13920
#
#        product_class product_size InvoiceDate
# count          19445        19445       19445
# unique             3            3         364
# top           medium       medium  2017-08-18
# freq           13587        12767          81

# %%
kategorik.nunique()
# Out:
# transaction_date    364
# online_order          2
# order_status          2
# brand                 6
# product_line          4
# product_class         3
# product_size          3
# InvoiceDate         364
# dtype: int64

# %%
# ambil semua yg kategorik
kategorik = df.select_dtypes(include = 'object')

plt.figure(figsize = (15,10)) # (kolom, bairs)
posisi = 1
for kolom in kategorik.columns:
    plt.subplot(3, 3, posisi) # (baris, kolom, posisi)
    sns.barplot(df[kolom].value_counts().sort_values(ascending = False).head(5), orient = 'h')
    posisi += 1
    plt.tight_layout() # biar tidak bertabrakan

# mengeprint grafik
plt.show()

# %%
# cek tipe data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19445 entries, 0 to 19444
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           19445 non-null  int64
#  1   product_id               19445 non-null  int64
#  2   CustomerID               19445 non-null  int64
#  3   transaction_date         19445 non-null  object
#  4   online_order             19445 non-null  object
#  5   order_status             19445 non-null  object
#  6   brand                    19445 non-null  object
#  7   product_line             19445 non-null  object
#  8   product_class            19445 non-null  object
#  9   product_size             19445 non-null  object
#  10  list_price               19445 non-null  float64
#  11  standard_cost            19445 non-null  float64
#  12  product_first_sold_date  19445 non-null  float64
#  13  InvoiceDate              19445 non-null  object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 2.1+ MB

# %%
# ubah invocedate ke datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19445 entries, 0 to 19444
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           19445 non-null  int64
#  1   product_id               19445 non-null  int64
#  2   CustomerID               19445 non-null  int64
#  3   transaction_date         19445 non-null  object
#  4   online_order             19445 non-null  object
#  5   order_status             19445 non-null  object
#  6   brand                    19445 non-null  object
#  7   product_line             19445 non-null  object
#  8   product_class            19445 non-null  object
#  9   product_size             19445 non-null  object
#  10  list_price               19445 non-null  float64
#  11  standard_cost            19445 non-null  float64
#  12  product_first_sold_date  19445 non-null  float64
#  13  InvoiceDate              19445 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(3), object(7)
# memory usage: 2.1+ MB

# %%
# ubah invocedate ke datetime
df['transaction_date'] = pd.to_datetime(df['transaction_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19445 entries, 0 to 19444
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           19445 non-null  int64
#  1   product_id               19445 non-null  int64
#  2   CustomerID               19445 non-null  int64
#  3   transaction_date         19445 non-null  datetime64[ns]
#  4   online_order             19445 non-null  object
#  5   order_status             19445 non-null  object
#  6   brand                    19445 non-null  object
#  7   product_line             19445 non-null  object
#  8   product_class            19445 non-null  object
#  9   product_size             19445 non-null  object
#  10  list_price               19445 non-null  float64
#  11  standard_cost            19445 non-null  float64
#  12  product_first_sold_date  19445 non-null  float64
#  13  InvoiceDate              19445 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(3), object(6)
# memory usage: 2.1+ MB

# %%
df['InvoiceDate'].dt.month
# Out:
# 0         2
# 1         5
# 2        10
# 3         8
# 4        10
#          ..
# 19440     6
# 19441    11
# 19442     4
# 19443     7
# 19444     9
# Name: InvoiceDate, Length: 19445, dtype: int32

# %%
# cek data yang statusnya cancel
df[df['order_status'] == 'Cancelled']
# Out:
#        transaction_id  product_id  CustomerID transaction_date online_order  \
# 42                 43          76         488       2017-03-17        False
# 136               139          32        2073       2017-03-25        False
# 244               250          48        1454       2017-11-25        False
# 248               255          67        2801       2017-04-01         True
# 567               584          43        1019       2017-09-13         True
# ...               ...         ...         ...              ...          ...
# 18860           19406          79        1860       2017-05-29        False
# 18864           19410          79        1771       2017-01-15        False
# 19270           19823           3        2312       2017-12-02        False
# 19402           19958          56        2013       2017-06-04         True
# 19434           19990          55         135       2017-01-27         True
#
#       order_status           brand product_line product_class product_size  \
# 42       Cancelled        WeareA2B     Standard           low       medium
# 136      Cancelled  Giant Bicycles     Standard          high       medium
# 244      Cancelled        WeareA2B     Standard        medium       medium
# 248      Cancelled  Norco Bicycles         Road        medium       medium
# 567      Cancelled           Solex     Standard        medium       medium
# ...            ...             ...          ...           ...          ...
# 18860    Cancelled  Norco Bicycles     Standard        medium       medium
# 18864    Cancelled  Norco Bicycles     Standard        medium       medium
# 19270    Cancelled   Trek Bicycles     Standard        medium        large
# 19402    Cancelled      OHM Cycles     Standard        medium       medium
# 19434    Cancelled   Trek Bicycles         Road        medium        large
#
#        list_price  standard_cost  product_first_sold_date InvoiceDate
# 42         642.31         513.85                  41922.0  2017-03-17
# 136       1179.00         707.40                  36833.0  2017-03-25
# 244       1762.96         950.52                  35470.0  2017-11-25
# 248        544.05         376.84                  38647.0  2017-04-01
# 567       1151.96         649.49                  34071.0  2017-09-13
# ...           ...            ...                      ...         ...
# 18860     1555.58         818.01                  42218.0  2017-05-29
# 18864     1555.58         818.01                  42226.0  2017-01-15
# 19270     2091.47         388.92                  36361.0  2017-12-02
# 19402      183.86         137.90                  34170.0  2017-06-04
# 19434     1894.19         598.76                  37823.0  2017-01-27
#
# [172 rows x 14 columns]

# %%
# mengambil data kecuali cancel pada order_status
df = df[df['order_status'] != 'Cancelled']
df
# Out:
#        transaction_id  product_id  CustomerID transaction_date online_order  \
# 0                   1           2        2950       2017-02-25        False
# 1                   2           3        3120       2017-05-21         True
# 2                   3          37         402       2017-10-16        False
# 3                   4          88        3135       2017-08-31        False
# 4                   5          78         787       2017-10-01         True
# ...               ...         ...         ...              ...          ...
# 19440           19996          51        1018       2017-06-24         True
# 19441           19997          41         127       2017-11-09         True
# 19442           19998          87        2284       2017-04-14         True
# 19443           19999           6        2764       2017-07-03        False
# 19444           20000          11        1144       2017-09-22         True
#
#       order_status           brand product_line product_class product_size  \
# 0         Approved           Solex     Standard        medium       medium
# 1         Approved   Trek Bicycles     Standard        medium        large
# 2         Approved      OHM Cycles     Standard           low       medium
# 3         Approved  Norco Bicycles     Standard        medium       medium
# 4         Approved  Giant Bicycles     Standard        medium        large
# ...            ...             ...          ...           ...          ...
# 19440     Approved      OHM Cycles     Standard          high       medium
# 19441     Approved           Solex         Road        medium       medium
# 19442     Approved      OHM Cycles     Standard        medium       medium
# 19443     Approved      OHM Cycles     Standard          high       medium
# 19444     Approved   Trek Bicycles     Standard        medium        small
#
#        list_price  standard_cost  product_first_sold_date InvoiceDate
# 0           71.49          53.62                  41245.0  2017-02-25
# 1         2091.47         388.92                  41701.0  2017-05-21
# 2         1793.43         248.82                  36361.0  2017-10-16
# 3         1198.46         381.10                  36145.0  2017-08-31
# 4         1765.30         709.48                  42226.0  2017-10-01
# ...           ...            ...                      ...         ...
# 19440     2005.66        1203.40                  37823.0  2017-06-24
# 19441      416.98         312.74                  35560.0  2017-11-09
# 19442     1636.90          44.71                  40410.0  2017-04-14
# 19443      227.88         136.73                  38216.0  2017-07-03
# 19444     1775.81        1580.47                  36334.0  2017-09-22
#
# [19273 rows x 14 columns]

# %% [markdown]
# ## Recency

# %%
# Menentukan tanggal terakhir dalam dataset
current_date = df['transaction_date'].max()
current_date
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
# mencari tanggal terakhir (last transaction) untuk setiap customer

last_transaction = df.groupby('CustomerID')['InvoiceDate'].max()
last_transaction
# Out:
# CustomerID
# 1      2017-12-23
# 2      2017-08-24
# 3      2017-09-19
# 4      2017-06-18
# 5      2017-12-14
#           ...
# 3497   2017-11-08
# 3498   2017-08-25
# 3499   2017-11-09
# 3500   2017-08-08
# 5034   2017-10-07
# Name: InvoiceDate, Length: 3490, dtype: datetime64[ns]

# %%
# mencari selisih antara tanggal terkini (current date) dengan tanggal terakhir customer belanja

recency = current_date - last_transaction
recency
# Out:
# CustomerID
# 1        7 days
# 2      128 days
# 3      102 days
# 4      195 days
# 5       16 days
#          ...
# 3497    52 days
# 3498   127 days
# 3499    51 days
# 3500   144 days
# 5034    84 days
# Name: InvoiceDate, Length: 3490, dtype: timedelta64[ns]

# %%
# karena hanya membutuhkan harinya saja makanya make dt.days
recency = (current_date - last_transaction).dt.days
recency = recency.rename('Recency')
recency
# Out:
# CustomerID
# 1         7
# 2       128
# 3       102
# 4       195
# 5        16
#        ...
# 3497     52
# 3498    127
# 3499     51
# 3500    144
# 5034     84
# Name: Recency, Length: 3490, dtype: int64

# %% [markdown]
# ## Frequency

# %%
frequency = df.groupby('CustomerID')['transaction_id'].count().rename('Frequency')
frequency
# Out:
# CustomerID
# 1       11
# 2        3
# 3        7
# 4        2
# 5        6
#         ..
# 3497     3
# 3498     6
# 3499     7
# 3500     6
# 5034     3
# Name: Frequency, Length: 3490, dtype: int64

# %% [markdown]
# ## Monetary

# %%
monetary = df.groupby('CustomerID')['list_price'].sum().rename('Monetary')
monetary
# Out:
# CustomerID
# 1       9084.45
# 2       4149.07
# 3       9525.22
# 4       1047.72
# 5       5903.20
#          ...
# 3497    3744.07
# 3498    5177.06
# 3499    7673.48
# 3500    4922.41
# 5034    1519.92
# Name: Monetary, Length: 3490, dtype: float64

# %% [markdown]
# ## DataFrame

# %%
rfm = pd.DataFrame({
        'Recency': recency,
        'Frequency': frequency,
        'Monetary': monetary
}).reset_index()
rfm
# Out:
#       CustomerID  Recency  Frequency  Monetary
# 0              1        7         11   9084.45
# 1              2      128          3   4149.07
# 2              3      102          7   9525.22
# 3              4      195          2   1047.72
# 4              5       16          6   5903.20
# ...          ...      ...        ...       ...
# 3485        3497       52          3   3744.07
# 3486        3498      127          6   5177.06
# 3487        3499       51          7   7673.48
# 3488        3500      144          6   4922.41
# 3489        5034       84          3   1519.92
#
# [3490 rows x 4 columns]

# %%
round(rfm.describe(),2)
# Out:
#        CustomerID  Recency  Frequency  Monetary
# count     3490.00  3490.00    3490.00   3490.00
# mean      1750.09    62.85       5.52   6113.58
# std       1011.35    59.37       2.28   2898.02
# min          1.00     0.00       1.00     60.34
# 25%        876.25    18.00       4.00   4023.00
# 50%       1749.50    45.00       5.00   5829.05
# 75%       2622.75    88.00       7.00   7934.46
# max       5034.00   353.00      14.00  19071.32

# %%
rfm.sort_values('Frequency', ascending = False).head(20)
# Out:
#       CustomerID  Recency  Frequency  Monetary
# 2470        2476       14         14  14578.69
# 2177        2183        8         14  19071.32
# 1064        1068        4         14  14254.55
# 1941        1946       88         13  11237.38
# 635          637        7         13  13899.73
# 1908        1913       42         13   8621.87
# 2067        2072        8         13  11845.44
# 2904        2912       46         13  14149.73
# 1125        1129       26         13  18349.27
# 2458        2464        2         13  14574.06
# 3315        3326       29         13  14078.19
# 1298        1302       29         13  17035.83
# 3222        3232        8         13  13451.28
# 38            39       34         12  11237.19
# 2542        2548        3         12  13610.10
# 1477        1482       68         12  14366.26
# 2906        2914       12         12  13824.53
# 959          963       60         12  12068.12
# 2234        2240       31         12  13961.45
# 1816        1821       24         12  14387.59

# %% [markdown]
# ## Histogram dan Boxplot (RFM)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))

plt.subplot(3,1,1)
sns.histplot(rfm['Recency'], kde=True)

plt.subplot(3,1,2)
sns.histplot(rfm['Frequency'], kde=True)

plt.subplot(3,1,3)
sns.histplot(rfm['Monetary'], kde=True)


plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))

plt.subplot(3,1,1)
sns.boxplot(x = rfm['Recency'])

plt.subplot(3,1,2)
sns.boxplot(x = rfm['Frequency'])

plt.subplot(3,1,3)
sns.boxplot(x = rfm['Monetary'])


plt.tight_layout()
plt.show()

# %% [markdown]
# - Recency
#   - Customer kita kebanyakan membeli 20-80 hari yang lalu (cukup baru)
# - Frequency
#   - customer kita kebanyakan baru 4 sampai 7 kali membeli ulang / re purcase
# - Monetary
#   - customer kita kebanyakan 4000 dollar sampai 7900 dollar

# %%
# mendefinisikan score dari statistika deskriftifnya
rfm.describe()
# Out:
#         CustomerID      Recency    Frequency      Monetary
# count  3490.000000  3490.000000  3490.000000   3490.000000
# mean   1750.092837    62.847564     5.522350   6113.584424
# std    1011.348380    59.365082     2.275693   2898.017543
# min       1.000000     0.000000     1.000000     60.340000
# 25%     876.250000    18.000000     4.000000   4023.002500
# 50%    1749.500000    45.000000     5.000000   5829.050000
# 75%    2622.750000    88.000000     7.000000   7934.462500
# max    5034.000000   353.000000    14.000000  19071.320000

# %% [markdown]
# ## RFM SCORE

# %%
def rfm_score(baris):
  #recency
  if baris['Recency'] <= 18: # dari nilai kuartil 1 / 25%
    r = 4
  elif baris['Recency'] <= 45: # kuartil 2 / 50%
    r = 3
  elif baris['Recency'] <= 88: # kuartil 3 / 75%
    r = 2
  else:
    r = 1

  #frequncy
  if baris['Frequency'] <= 3: #Q1
    f = 1
  elif baris['Frequency'] <= 5: #Q2
    f = 2
  elif baris['Frequency'] <= 10: #Q3
    f = 3
  else:
    f = 4

  #monetary
  if baris['Monetary'] <= 4000: #Q1 / kuartil 1
    m = 1
  elif baris['Monetary'] <= 5800: #Q2
    m = 2
  elif baris['Monetary'] <= 7900: #Q3
    m = 3
  else:
    m = 4


  return pd.Series({'R_Score': r, 'F_Score': f, 'M_Score': m})

rfm[['R_Score', 'F_Score', 'M_Score']] = rfm.apply(rfm_score, axis=1)
rfm['RFM_Score'] = rfm['R_Score'] + rfm['F_Score'] + rfm['M_Score']
rfm
# Out:
#       CustomerID  Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# 0              1        7         11   9084.45        4        4        4
# 1              2      128          3   4149.07        1        1        2
# 2              3      102          7   9525.22        1        3        4
# 3              4      195          2   1047.72        1        1        1
# 4              5       16          6   5903.20        4        3        3
# ...          ...      ...        ...       ...      ...      ...      ...
# 3485        3497       52          3   3744.07        2        1        1
# 3486        3498      127          6   5177.06        1        3        2
# 3487        3499       51          7   7673.48        2        3        3
# 3488        3500      144          6   4922.41        1        3        2
# 3489        5034       84          3   1519.92        2        1        1
#
#       RFM_Score
# 0            12
# 1             4
# 2             8
# 3             3
# 4            10
# ...         ...
# 3485          4
# 3486          6
# 3487          8
# 3488          6
# 3489          4
#
# [3490 rows x 8 columns]

# %%
rfm['Rank'] = rfm['Monetary'].rank(method='dense', ascending=False)

# Menampilkan hasil dengan sorting berdasarkan ranking
rfm = rfm.sort_values('Rank')

rfm
# Out:
#       CustomerID  Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# 2177        2183        8         14  19071.32        4        4        4
# 1125        1129       26         13  18349.27        3        4        4
# 937          941       33         10  17898.46        3        3        4
# 2781        2788       44         11  17258.94        3        4        4
# 1298        1302       29         13  17035.83        3        4        4
# ...          ...      ...        ...       ...      ...      ...      ...
# 2417        2423       59          1    202.62        2        1        1
# 3180        3189       56          2    200.70        2        1        1
# 2268        2274       55          2    142.98        2        1        1
# 2526        2532      140          1     71.49        1        1        1
# 3281        3292      301          1     60.34        1        1        1
#
#       RFM_Score    Rank
# 2177         12     1.0
# 1125         11     2.0
# 937          10     3.0
# 2781         11     4.0
# 1298         11     5.0
# ...         ...     ...
# 2417          4  3459.0
# 3180          4  3460.0
# 2268          4  3461.0
# 2526          3  3462.0
# 3281          3  3463.0
#
# [3490 rows x 9 columns]

# %% [markdown]
# ## RFM Segmentation

# %%
#  SEPERTI KATEGORI PADA SHOPEE YAITU PLATINUM, GOLD

rfm['FM_Score'] = rfm['F_Score'] + rfm['M_Score']

# Manual Clustering using IF-ELSE Conditions
def segment_customer(row):
    recency = row['R_Score']
    fm_combined = row['FM_Score']
    if recency >= 4 and fm_combined >= 4:
        return 'Champions'
    elif recency >= 3 and fm_combined >= 3:
        return 'Loyal Customers'
    elif recency >= 2 and fm_combined >= 3:
        return 'Potential Loyalist'
    elif recency >= 3 and fm_combined <= 2:
        return 'Promising'
    elif recency < 2 and fm_combined >= 3:
        return 'At Risk'
    elif recency < 2 and fm_combined <= 2:
        return 'Lost'
    else:
        return 'Uncategorized'

# Apply the segmentation function
rfm['Customer_Segment'] = rfm.apply(segment_customer, axis=1)
rfm
# Out:
#       CustomerID  Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# 2177        2183        8         14  19071.32        4        4        4
# 1125        1129       26         13  18349.27        3        4        4
# 937          941       33         10  17898.46        3        3        4
# 2781        2788       44         11  17258.94        3        4        4
# 1298        1302       29         13  17035.83        3        4        4
# ...          ...      ...        ...       ...      ...      ...      ...
# 2417        2423       59          1    202.62        2        1        1
# 3180        3189       56          2    200.70        2        1        1
# 2268        2274       55          2    142.98        2        1        1
# 2526        2532      140          1     71.49        1        1        1
# 3281        3292      301          1     60.34        1        1        1
#
#       RFM_Score    Rank  FM_Score Customer_Segment
# 2177         12     1.0         8        Champions
# 1125         11     2.0         8  Loyal Customers
# 937          10     3.0         7  Loyal Customers
# 2781         11     4.0         8  Loyal Customers
# 1298         11     5.0         8  Loyal Customers
# ...         ...     ...       ...              ...
# 2417          4  3459.0         2    Uncategorized
# 3180          4  3460.0         2    Uncategorized
# 2268          4  3461.0         2    Uncategorized
# 2526          3  3462.0         2             Lost
# 3281          3  3463.0         2             Lost
#
# [3490 rows x 11 columns]
